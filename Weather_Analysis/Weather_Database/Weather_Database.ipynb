# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=055946d75d1fde893f63ae7c23bde5fc

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | husavik
# Processing Record 2 of Set 1 | anadyr
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | loikaw
# Processing Record 5 of Set 1 | ostrovnoy
# Processing Record 6 of Set 1 | te anau
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | behbahan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | villa bruzual
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | port keats
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | ovalle
# Processing Record 24 of Set 1 | hastings
# Processing Record 25 of Set 1 | darnah
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | bilgoraj
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | yinchuan
# Processing Record 32 of Set 1 | lavrentiya
# Processing Record 33 of Set 1 | sibolga
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | lavumisa
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | balkanabat
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | omsukchan
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | ixtapa
# Processing Record 44 of Set 1 | klyuchi
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | knysna
# Processing Record 47 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 1 | spasskoye
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | dire
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | san cristobal
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | the valley
# Processing Record 5 of Set 2 | naze
# Processing Record 6 of Set 2 | esna
# Processing Record 7 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 2 | belaya gora
# Processing Record 10 of Set 2 | ratodero
# Processing Record 11 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | udachnyy
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | laurel
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 2 | cayenne
# Processing Record 24 of Set 2 | riyadh
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | sharan
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | iranshahr
# Processing Record 30 of Set 2 | luebo
# Processing Record 31 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 32 of Set 2 | carora
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | skjervoy
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 2 | marawi
# Processing Record 38 of Set 2 | nouakchott
# Processing Record 39 of Set 2 | zaterechnyy
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | sungaipenuh
# Processing Record 43 of Set 2 | opuwo
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | north platte
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | zabinka
# City not found. Skipping...
# Processing Record 48 of Set 2 | zeerust
# Processing Record 49 of Set 2 | zaliznychne
# Processing Record 50 of Set 2 | volksrust
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | labuhan
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | rio grande
# Processing Record 9 of Set 3 | sao felix do xingu
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | umm lajj
# Processing Record 15 of Set 3 | luganville
# Processing Record 16 of Set 3 | roma
# Processing Record 17 of Set 3 | jaguarari
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | kostino
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | north myrtle beach
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | sakakah
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | victor harbor
# Processing Record 28 of Set 3 | kulu
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | senno
# Processing Record 31 of Set 3 | komsomolskiy
# Processing Record 32 of Set 3 | huarmey
# Processing Record 33 of Set 3 | keti bandar
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | chernyshevskiy
# Processing Record 36 of Set 3 | suoyarvi
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | gaoual
# Processing Record 45 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 3 | colares
# Processing Record 47 of Set 3 | lockhart
# Processing Record 48 of Set 3 | camacupa
# Processing Record 49 of Set 3 | palanga
# Processing Record 50 of Set 3 | cam ranh
# Processing Record 1 of Set 4 | kolosovka
# Processing Record 2 of Set 4 | pisco
# Processing Record 3 of Set 4 | smithers
# Processing Record 4 of Set 4 | madimba
# Processing Record 5 of Set 4 | rocha
# Processing Record 6 of Set 4 | cozumel
# Processing Record 7 of Set 4 | kupang
# Processing Record 8 of Set 4 | avera
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | kant
# Processing Record 11 of Set 4 | cururupu
# Processing Record 12 of Set 4 | ulaangom
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | tunghsiao
# City not found. Skipping...
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | suleja
# Processing Record 20 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 21 of Set 4 | killybegs
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | wewak
# Processing Record 24 of Set 4 | kaseda
# Processing Record 25 of Set 4 | burnie
# Processing Record 26 of Set 4 | douglas
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | kaihua
# Processing Record 29 of Set 4 | atambua
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | tonekabon
# Processing Record 32 of Set 4 | kavaratti
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | talca
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | santa maria da vitoria
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | ordzhonikidze
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | currais novos
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | isla vista
# Processing Record 45 of Set 4 | yashkul
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | bridlington
# Processing Record 48 of Set 4 | florianopolis
# Processing Record 49 of Set 4 | zimnicea
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | pangnirtung
# Processing Record 2 of Set 5 | yar-sale
# Processing Record 3 of Set 5 | sept-iles
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | amapa
# Processing Record 6 of Set 5 | coihueco
# Processing Record 7 of Set 5 | auxerre
# Processing Record 8 of Set 5 | cuiluan
# Processing Record 9 of Set 5 | shihezi
# Processing Record 10 of Set 5 | nizhnyaya omka
# Processing Record 11 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | lebanon
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | bela vista
# Processing Record 16 of Set 5 | walvis bay
# Processing Record 17 of Set 5 | griffith
# Processing Record 18 of Set 5 | rockport
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | honiara
# Processing Record 22 of Set 5 | nelson bay
# Processing Record 23 of Set 5 | port blair
# Processing Record 24 of Set 5 | lhokseumawe
# Processing Record 25 of Set 5 | makaryev
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | leeton
# Processing Record 28 of Set 5 | norman wells
# Processing Record 29 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 5 | kathmandu
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | oranjemund
# Processing Record 33 of Set 5 | kulhudhuffushi
# Processing Record 34 of Set 5 | baiyin
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | chumikan
# Processing Record 37 of Set 5 | mbalmayo
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | tevriz
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | kastamonu
# Processing Record 42 of Set 5 | qianan
# Processing Record 43 of Set 5 | cap malheureux
# Processing Record 44 of Set 5 | hamilton
# Processing Record 45 of Set 5 | kusti
# Processing Record 46 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 5 | stephenville
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | nizwa
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | sindou
# Processing Record 2 of Set 6 | kutum
# Processing Record 3 of Set 6 | redmond
# Processing Record 4 of Set 6 | presidente epitacio
# Processing Record 5 of Set 6 | svetlyy
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | soyo
# Processing Record 8 of Set 6 | port-gentil
# Processing Record 9 of Set 6 | saryozek
# Processing Record 10 of Set 6 | buchanan
# Processing Record 11 of Set 6 | harper
# Processing Record 12 of Set 6 | telemaco borba
# Processing Record 13 of Set 6 | verkhniye achaluki
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | evanston
# Processing Record 16 of Set 6 | yeppoon
# Processing Record 17 of Set 6 | lasa
# Processing Record 18 of Set 6 | laguna
# Processing Record 19 of Set 6 | jinchang
# Processing Record 20 of Set 6 | kitimat
# Processing Record 21 of Set 6 | sakhipur
# Processing Record 22 of Set 6 | faanui
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | meulaboh
# Processing Record 25 of Set 6 | matara
# Processing Record 26 of Set 6 | sorland
# Processing Record 27 of Set 6 | hobyo
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | dalianwan
# Processing Record 30 of Set 6 | wyndham
# Processing Record 31 of Set 6 | ouadda
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | nylstroom
# City not found. Skipping...
# Processing Record 34 of Set 6 | kavieng
# Processing Record 35 of Set 6 | codrington
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | bumba
# Processing Record 38 of Set 6 | coolum beach
# Processing Record 39 of Set 6 | sulangan
# Processing Record 40 of Set 6 | yumen
# Processing Record 41 of Set 6 | chirongui
# Processing Record 42 of Set 6 | karmana
# City not found. Skipping...
# Processing Record 43 of Set 6 | pargolovo
# Processing Record 44 of Set 6 | kribi
# Processing Record 45 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | cooma
# Processing Record 47 of Set 6 | tantoyuca
# Processing Record 48 of Set 6 | bereda
# Processing Record 49 of Set 6 | eruwa
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | porto nacional
# Processing Record 2 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 7 | poum
# Processing Record 4 of Set 7 | ust-tsilma
# Processing Record 5 of Set 7 | fairbanks
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | sorong
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | easton
# Processing Record 10 of Set 7 | stonewall
# Processing Record 11 of Set 7 | saskylakh
# Processing Record 12 of Set 7 | nanortalik
# Processing Record 13 of Set 7 | wuda
# Processing Record 14 of Set 7 | nadym
# Processing Record 15 of Set 7 | coahuayana
# Processing Record 16 of Set 7 | aykhal
# Processing Record 17 of Set 7 | mnogovershinnyy
# Processing Record 18 of Set 7 | bengkulu
# Processing Record 19 of Set 7 | agadir
# Processing Record 20 of Set 7 | caribou
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 7 | suluq
# Processing Record 25 of Set 7 | pevek
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | angoche
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 30 of Set 7 | pathein
# Processing Record 31 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 7 | cabanas
# Processing Record 33 of Set 7 | maxixe
# Processing Record 34 of Set 7 | provideniya
# Processing Record 35 of Set 7 | derzhavinsk
# Processing Record 36 of Set 7 | qeshm
# Processing Record 37 of Set 7 | viedma
# Processing Record 38 of Set 7 | yerbogachen
# Processing Record 39 of Set 7 | quelimane
# Processing Record 40 of Set 7 | pemba
# Processing Record 41 of Set 7 | fort nelson
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | muros
# Processing Record 45 of Set 7 | severo-kurilsk
# Processing Record 46 of Set 7 | dorchester
# Processing Record 47 of Set 7 | talnakh
# Processing Record 48 of Set 7 | cherskiy
# Processing Record 49 of Set 7 | ban phai
# Processing Record 50 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | kogon
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | vlasim
# Processing Record 4 of Set 8 | marshall
# Processing Record 5 of Set 8 | kayerkan
# Processing Record 6 of Set 8 | erdenet
# Processing Record 7 of Set 8 | evensk
# Processing Record 8 of Set 8 | rio gallegos
# Processing Record 9 of Set 8 | fuerte olimpo
# Processing Record 10 of Set 8 | curup
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | bambous virieux
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | barcelos
# Processing Record 16 of Set 8 | quatre cocos
# Processing Record 17 of Set 8 | bonthe
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | robertsport
# Processing Record 20 of Set 8 | marzuq
# Processing Record 21 of Set 8 | buraydah
# Processing Record 22 of Set 8 | floro
# Processing Record 23 of Set 8 | ciudad bolivar
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | verkhoyansk
# Processing Record 26 of Set 8 | honningsvag
# Processing Record 27 of Set 8 | atikokan
# Processing Record 28 of Set 8 | myitkyina
# Processing Record 29 of Set 8 | mount gambier
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | parasia
# Processing Record 32 of Set 8 | miri
# Processing Record 33 of Set 8 | shu
# Processing Record 34 of Set 8 | amot
# Processing Record 35 of Set 8 | cruzeiro do sul
# Processing Record 36 of Set 8 | cap-aux-meules
# Processing Record 37 of Set 8 | samarai
# Processing Record 38 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 8 | kapuskasing
# Processing Record 40 of Set 8 | ballina
# Processing Record 41 of Set 8 | inirida
# Processing Record 42 of Set 8 | qui nhon
# Processing Record 43 of Set 8 | abha
# Processing Record 44 of Set 8 | oxford
# Processing Record 45 of Set 8 | iqaluit
# Processing Record 46 of Set 8 | chabahar
# Processing Record 47 of Set 8 | lompoc
# Processing Record 48 of Set 8 | dembi dolo
# Processing Record 49 of Set 8 | bhag
# Processing Record 50 of Set 8 | isla mujeres
# Processing Record 1 of Set 9 | zarichne
# Processing Record 2 of Set 9 | belogorsk
# Processing Record 3 of Set 9 | nador
# Processing Record 4 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | adrar
# Processing Record 7 of Set 9 | jacksonville
# Processing Record 8 of Set 9 | jiangyou
# Processing Record 9 of Set 9 | ahuimanu
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | los llanos de aridane
# Processing Record 12 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 9 | kashi
# Processing Record 14 of Set 9 | kangly
# Processing Record 15 of Set 9 | asbury park
# Processing Record 16 of Set 9 | villarrica
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | great yarmouth
# Processing Record 19 of Set 9 | antofagasta
# Processing Record 20 of Set 9 | tolaga bay
# Processing Record 21 of Set 9 | duncan
# Processing Record 22 of Set 9 | tagusao
# Processing Record 23 of Set 9 | erenhot
# Processing Record 24 of Set 9 | jieshi
# Processing Record 25 of Set 9 | lisieux
# Processing Record 26 of Set 9 | conceicao do araguaia
# Processing Record 27 of Set 9 | abu dhabi
# Processing Record 28 of Set 9 | kikwit
# Processing Record 29 of Set 9 | nicoya
# Processing Record 30 of Set 9 | siyabuswa
# Processing Record 31 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 32 of Set 9 | ambilobe
# Processing Record 33 of Set 9 | necochea
# Processing Record 34 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 9 | mae sai
# Processing Record 36 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 9 | tabou
# Processing Record 38 of Set 9 | becerril
# Processing Record 39 of Set 9 | sale
# Processing Record 40 of Set 9 | mae ramat
# Processing Record 41 of Set 9 | alyangula
# Processing Record 42 of Set 9 | bolshoye selo
# Processing Record 43 of Set 9 | duz
# City not found. Skipping...
# Processing Record 44 of Set 9 | wawa
# Processing Record 45 of Set 9 | falavarjan
# Processing Record 46 of Set 9 | severnoye
# Processing Record 47 of Set 9 | lerwick
# Processing Record 48 of Set 9 | campos novos
# Processing Record 49 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 9 | nizhniy kuranakh
# Processing Record 1 of Set 10 | lalsk
# Processing Record 2 of Set 10 | sangar
# Processing Record 3 of Set 10 | agirish
# Processing Record 4 of Set 10 | pemangkat
# Processing Record 5 of Set 10 | smidovich
# Processing Record 6 of Set 10 | dabat
# Processing Record 7 of Set 10 | kjollefjord
# Processing Record 8 of Set 10 | goderich
# Processing Record 9 of Set 10 | tessalit
# Processing Record 10 of Set 10 | forest grove
# Processing Record 11 of Set 10 | churapcha
# Processing Record 12 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 13 of Set 10 | terme
# Processing Record 14 of Set 10 | luderitz
# Processing Record 15 of Set 10 | coihaique
# Processing Record 16 of Set 10 | san jose
# Processing Record 17 of Set 10 | guanica
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | kuusamo
# Processing Record 20 of Set 10 | shalya
# Processing Record 21 of Set 10 | kaeo
# Processing Record 22 of Set 10 | jacareacanga
# Processing Record 23 of Set 10 | turayf
# Processing Record 24 of Set 10 | mayo
# Processing Record 25 of Set 10 | richards bay
# Processing Record 26 of Set 10 | varhaug
# Processing Record 27 of Set 10 | grindavik
# Processing Record 28 of Set 10 | paamiut
# Processing Record 29 of Set 10 | kapustin yar-1
# City not found. Skipping...
# Processing Record 30 of Set 10 | balikpapan
# Processing Record 31 of Set 10 | sabancuy
# Processing Record 32 of Set 10 | indianola
# Processing Record 33 of Set 10 | ayni
# Processing Record 34 of Set 10 | kieta
# Processing Record 35 of Set 10 | teya
# Processing Record 36 of Set 10 | pimentel
# Processing Record 37 of Set 10 | klaksvik
# Processing Record 38 of Set 10 | anshun
# Processing Record 39 of Set 10 | nabire
# Processing Record 40 of Set 10 | sao joao da barra
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | paulista
# Processing Record 43 of Set 10 | uvira
# Processing Record 44 of Set 10 | manokwari
# Processing Record 45 of Set 10 | ewa beach
# Processing Record 46 of Set 10 | axente sever
# Processing Record 47 of Set 10 | batemans bay
# Processing Record 48 of Set 10 | seydi
# Processing Record 49 of Set 10 | kandrian
# Processing Record 50 of Set 10 | dingle
# Processing Record 1 of Set 11 | sokoto
# Processing Record 2 of Set 11 | salalah
# Processing Record 3 of Set 11 | ternate
# Processing Record 4 of Set 11 | rudbar
# Processing Record 5 of Set 11 | codo
# Processing Record 6 of Set 11 | valcourt
# Processing Record 7 of Set 11 | kotelnikovo
# Processing Record 8 of Set 11 | rock sound
# Processing Record 9 of Set 11 | mirnyy
# Processing Record 10 of Set 11 | santiago del estero
# Processing Record 11 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 11 | kaduqli
# Processing Record 13 of Set 11 | nishihara
# Processing Record 14 of Set 11 | cidreira
# Processing Record 15 of Set 11 | hovd
# Processing Record 16 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 11 | xining
# Processing Record 18 of Set 11 | okmulgee
# Processing Record 19 of Set 11 | itarema
# Processing Record 20 of Set 11 | waipawa
# Processing Record 21 of Set 11 | segezha
# Processing Record 22 of Set 11 | wattegama
# Processing Record 23 of Set 11 | schela
# Processing Record 24 of Set 11 | ilhabela
# Processing Record 25 of Set 11 | tahta
# Processing Record 26 of Set 11 | jesus
# Processing Record 27 of Set 11 | poim
# Processing Record 28 of Set 11 | urengoy
# Processing Record 29 of Set 11 | ugoofaaru
# Processing Record 30 of Set 11 | hostotipaquillo
# Processing Record 31 of Set 11 | zarand
# Processing Record 32 of Set 11 | placido de castro
# Processing Record 33 of Set 11 | nove hrady
# Processing Record 34 of Set 11 | sosnovo-ozerskoye
# Processing Record 35 of Set 11 | ardabil
# Processing Record 36 of Set 11 | zheleznodorozhnyy
# Processing Record 37 of Set 11 | teguldet
# Processing Record 38 of Set 11 | tazovskiy
# Processing Record 39 of Set 11 | ayan
# Processing Record 40 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 41 of Set 11 | podgornoye
# Processing Record 42 of Set 11 | slonim
# Processing Record 43 of Set 11 | birao
# Processing Record 44 of Set 11 | charagua
# Processing Record 45 of Set 11 | nhulunbuy
# Processing Record 46 of Set 11 | eureka
# Processing Record 47 of Set 11 | shaki
# Processing Record 48 of Set 11 | yenagoa
# Processing Record 49 of Set 11 | kalmunai
# Processing Record 50 of Set 11 | olafsvik
# Processing Record 1 of Set 12 | aswan
# Processing Record 2 of Set 12 | bayburt
# Processing Record 3 of Set 12 | druzhba
# Processing Record 4 of Set 12 | dhidhdhoo
# Processing Record 5 of Set 12 | kaputa
# Processing Record 6 of Set 12 | hrebinka
# Processing Record 7 of Set 12 | aviles
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | pontianak
# Processing Record 10 of Set 12 | golden rock
# City not found. Skipping...
# Processing Record 11 of Set 12 | tautira
# Processing Record 12 of Set 12 | la ronge
# Processing Record 13 of Set 12 | virginia beach
# Processing Record 14 of Set 12 | cumbum
# Processing Record 15 of Set 12 | mehamn
# Processing Record 16 of Set 12 | vostok
# Processing Record 17 of Set 12 | wanning
# Processing Record 18 of Set 12 | karratha
# Processing Record 19 of Set 12 | mackay
# Processing Record 20 of Set 12 | egvekinot
# Processing Record 21 of Set 12 | araceli
# Processing Record 22 of Set 12 | rongcheng
# Processing Record 23 of Set 12 | pacific grove
# Processing Record 24 of Set 12 | nizhniy tsasuchey
# Processing Record 25 of Set 12 | ushtobe
# Processing Record 26 of Set 12 | khandyga
# Processing Record 27 of Set 12 | okhotsk
# Processing Record 28 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 12 | ekhabi
# Processing Record 30 of Set 12 | calamar
# Processing Record 31 of Set 12 | jizan
# Processing Record 32 of Set 12 | puerto escondido
# Processing Record 33 of Set 12 | pangody
# Processing Record 34 of Set 12 | billings
# Processing Record 35 of Set 12 | russell
# Processing Record 36 of Set 12 | kristiinankaupunki
# Processing Record 37 of Set 12 | nome
# Processing Record 38 of Set 12 | tazmalt
# Processing Record 39 of Set 12 | nakusp
# Processing Record 40 of Set 12 | yaan
# Processing Record 41 of Set 12 | tecoanapa
# Processing Record 42 of Set 12 | dehloran
# Processing Record 43 of Set 12 | santa marta
# Processing Record 44 of Set 12 | mucurapo
# Processing Record 45 of Set 12 | eagle pass
# Processing Record 46 of Set 12 | taloqan
# Processing Record 47 of Set 12 | bucerias
# Processing Record 48 of Set 12 | puerto carreno
# Processing Record 49 of Set 12 | usinsk
# Processing Record 50 of Set 12 | dunedin
# Processing Record 1 of Set 13 | floresta
# Processing Record 2 of Set 13 | jambi
# Processing Record 3 of Set 13 | kasulu
# Processing Record 4 of Set 13 | pinheiro
# Processing Record 5 of Set 13 | bose
# Processing Record 6 of Set 13 | santa cruz
# Processing Record 7 of Set 13 | sharkan
# Processing Record 8 of Set 13 | tecpan
# Processing Record 9 of Set 13 | aloleng
# Processing Record 10 of Set 13 | omboue
# Processing Record 11 of Set 13 | sunland park
# Processing Record 12 of Set 13 | bathurst
# Processing Record 13 of Set 13 | bani
# Processing Record 14 of Set 13 | tsiroanomandidy
# Processing Record 15 of Set 13 | mwinilunga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0    Husavik      IS  2021-11-02 10:41:34  66.0449  -17.3389     30.11
# 1     Anadyr      RU  2021-11-02 10:41:35  64.7500  177.4833    -12.50
# 2     Loikaw      MM  2021-11-02 10:41:35  19.6742   97.2094     69.71
# 3  Ostrovnoy      RU  2021-11-02 10:41:35  68.0531   39.5131     39.02
# 4    Te Anau      NZ  2021-11-02 10:41:36 -45.4167  167.7167     37.67
# 5     Avarua      CK  2021-11-02 10:41:36 -21.2078 -159.7750     75.25
# 6     Barrow      US  2021-11-02 10:41:36  71.2906 -156.7887     -2.18
# 7   Behbahan      IR  2021-11-02 10:41:37  30.5959   50.2417     94.32
# 8    Rikitea      PF  2021-11-02 10:41:37 -23.1203 -134.9692     72.19
# 9     Albany      US  2021-11-02 10:41:37  42.6001  -73.9662     42.15
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        86         100       21.47          light snow
# 1        77          20       13.42          few clouds
# 2        89          67        2.39       broken clouds
# 3        95         100       29.42     overcast clouds
# 4        93          39        4.00    scattered clouds
# 5        83          40       11.50    scattered clouds
# 6        84          20        8.05                mist
# 7        12           0       13.35           clear sky
# 8        77          98       15.48     overcast clouds
# 9        81          99        3.18     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
